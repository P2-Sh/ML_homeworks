# %%
print("Hello, world!")
n = 3
print(n)
# Out:
# Hello, world!
# 3

# %%
n = 10

if n % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
s = "abcdeqwerty"
print(s[::-1])
# Out:
# ytrewqedcba

# %%
a = [1, 2, 3]
a.append(4)
print(a)
print(a[1:3])
# Out:
# [1, 2, 3, 4]
# [2, 3]

# %%
a = {1, 2, 3}
a.add(4)
print(a)
a.add(4)
print(a)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}

# %%
a = {"x": 10, "y": 20}
print(a["x"])
# Out:
# 10

# %%
for n in range(5):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = 0

while n < 5:
    print(n)
    n += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = 0

while n < 5:
    print(n)
    n += 10
# Out:
# 0

# %%
a = [1, 2, 3, 4, 5]

for n in a:
    if n % 2 == 0:
        print(n)
# Out:
# 2
# 4

# %%
def f(a, b=10):
    return a + b

print(f(5))
print(f(5, 2))
# Out:
# 15
# 7

# %%
def f(*a):
    return sum(a)

print(f(1, 2, 3))
# Out:
# 6

# %%
a = lambda x: x ** 2
print(a(5))
# Out:
# 25

# %%
a = [1, 2, 3, 4]
print([x * 2 for x in a])
# Out:
# [2, 4, 6, 8]

# %%
try:
    print(10 / 0)
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("error")
# Out:
# error

# %%
import json

a = {"x": 1, "y": 2}

with open("a.json", "w") as f:
    json.dump(a, f)

# %%
import csv

with open("a.csv", "w", newline="") as f:
    csv.writer(f).writerow(["x", "y"])

import pandas as pd

df = pd.read_csv("a.csv")
print(df.head())
# Out:
# Empty DataFrame
# Columns: [x, y]
# Index: []

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
from datetime import datetime

print(datetime.now())
# Out:
# 2026-09-22 14:32:46.901945

# %%
import requests

a = requests.get("https://api.github.com")
print(a.status_code)
print(a)
# Out:
# 200
# <Response [200]>

# %%
a = requests.get("https://api.github.com/users/python").json()
print(a["login"])
# Out:
# python

# %%
class A:
    def __init__(self, x):
        self.x = x

    def f(self):
        print(self.x)

a = A(10)
a.f()
# Out:
# 10

# %%
class B(A):
    def __init__(self, x):
        self.x = x+10

a = B(10)
a.f()
# Out:
# 20
